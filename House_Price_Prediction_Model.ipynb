# %%
import pandas as pd

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()

file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)

df.head()
# Out:
#      <input type="file" id="files-8821c5b2-d42c-4c3b-9349-16ef091e6cf0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8821c5b2-d42c-4c3b-9349-16ef091e6cf0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
df['price'] = df['price'].astype(int)
df['bedrooms'] = df['bedrooms'].astype(int)

# %%
df.head()
# Out:
#                   date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000         3       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000         5       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000         3       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000         3       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.drop(['date', 'street', 'city', 'statezip', 'country'], axis=1, inplace=True)
df.head()
# Out:
#      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000         3       1.50         1340      7912     1.5           0
# 1  2384000         5       2.50         3650      9050     2.0           0
# 2   342000         3       2.00         1930     11947     1.0           0
# 3   420000         3       2.25         2000      8030     1.0           0
# 4   550000         4       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992

# %%
df.shape
# Out:
# (4600, 13)

# %%
null_counts = df.isnull().sum()

print(null_counts)
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# dtype: int64

# %%
desired_order = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot','floors','waterfront','view','condition','sqft_above','sqft_basement','yr_built','yr_renovated','price']
df = df[desired_order]
df.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.50         1340      7912     1.5           0     0
# 1         5       2.50         3650      9050     2.0           0     4
# 2         3       2.00         1930     11947     1.0           0     0
# 3         3       2.25         2000      8030     1.0           0     0
# 4         4       2.50         1940     10500     1.0           0     0
#
#    condition  sqft_above  sqft_basement  yr_built  yr_renovated    price
# 0          3        1340              0      1955          2005   313000
# 1          5        3370            280      1921             0  2384000
# 2          4        1930              0      1966             0   342000
# 3          4        1000           1000      1963             0   420000
# 4          4        1140            800      1976          1992   550000

# %%
df.describe()
# Out:
#           bedrooms    bathrooms   sqft_living      sqft_lot       floors  \
# count  4600.000000  4600.000000   4600.000000  4.600000e+03  4600.000000
# mean      3.400870     2.160815   2139.103478  1.485252e+04     1.512065
# std       0.908848     0.783781    963.159990  3.588444e+04     0.538288
# min       0.000000     0.000000    370.000000  6.380000e+02     1.000000
# 25%       3.000000     1.750000   1460.000000  5.000750e+03     1.000000
# 50%       3.000000     2.250000   1980.000000  7.683000e+03     1.500000
# 75%       4.000000     2.500000   2620.000000  1.100125e+04     2.000000
# max       9.000000     8.000000  13540.000000  1.074218e+06     3.500000
#
#         waterfront         view    condition   sqft_above  sqft_basement  \
# count  4600.000000  4600.000000  4600.000000  4600.000000    4600.000000
# mean      0.007174     0.240652     3.451739  1827.265435     312.081522
# std       0.084404     0.778405     0.677230   862.168977     464.137228
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

plt.figure(figsize=(15, 12))
columns_to_plot = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
                   'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
                   'yr_built', 'yr_renovated']

for i, column in enumerate(columns_to_plot, 1):
    plt.subplot(4, 4, i)
    sns.histplot(df[column], kde=True, bins=30, color='blue')
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_heatmap = df.corr()
sns.set(style="white")
plt.figure(figsize=(10, 8))
sns.heatmap(df_heatmap, cmap="coolwarm", annot=True, fmt=".2f", linewidths=.5)
plt.title("HeatMap of Data Set")
plt.show()

# %%
sns.pairplot(df)

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.countplot(x='waterfront', data=df, hue='waterfront', palette='viridis', legend=False)
plt.title('Distribution of Waterfront')

plt.subplot(1, 3, 2)
sns.countplot(x='view', data=df, hue='view', palette='viridis', legend=False)
plt.title('Distribution of View')

plt.subplot(1, 3, 3)
sns.countplot(x='condition', data=df, hue='condition', palette='viridis', legend=False)
plt.title('Distribution of Condition')

plt.show()

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.barplot(x='waterfront', y='price', data=df, hue='waterfront', palette='viridis', ci=None)
plt.title('Impact of Waterfront on Price')

plt.subplot(1, 3, 2)
sns.barplot(x='view', y='price', data=df, hue='view', palette='viridis', ci=None)
plt.title('Impact of View on Price')

plt.subplot(1, 3, 3)
sns.barplot(x='condition', y='price', data=df, hue='condition', palette='viridis', ci=None)
plt.title('Impact of Condition on Price')

plt.show()
# Out:
# <ipython-input-71-81f32109f27f>:22: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#
# <ipython-input-71-81f32109f27f>:26: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#
# <ipython-input-71-81f32109f27f>:30: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
sns.lineplot(x='yr_built', y=df['yr_built'].value_counts().sort_index().cumsum(), data=df)
plt.title('Houses Built Over Time')
plt.xlabel('Year Built')
plt.ylabel('Cumulative Count')

plt.subplot(1, 2, 2)
sns.lineplot(x='yr_renovated', y=df['yr_renovated'].value_counts().sort_index().cumsum(), data=df)
plt.title('Houses Renovated Over Time')
plt.xlabel('Year Renovated')
plt.ylabel('Cumulative Count')

plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
numerical_columns = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement']
plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(2, 4, i)
    sns.boxplot(x=df[column])
    plt.title(f'Box Plot of {column}')

plt.tight_layout()
plt.show()

# %%
import plotly.express as px
fig = px.scatter_3d(df, x='bedrooms', y='floors', z='price', color='price', opacity=0.8, size_max=15)
fig.update_layout(scene=dict(xaxis_title='Bedrooms', yaxis_title='Floors', zaxis_title='Price'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
scaler = StandardScaler()
df_standardized = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
X = df_standardized.iloc[:,:-1]
y = df_standardized.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split, cross_val_score
X_train, X_test, y_train, y_test =train_test_split(
  X, y, test_size = 0.2, random_state = 24)
print(f"Train: {X_train.shape}, {y_train.shape}")
print(f"Test: {X_test.shape}, {y_test.shape}")
# Out:
# Train: (3680, 12), (3680,)
# Test: (920, 12), (920,)

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# Assuming X_train, X_test, y_train, and y_test are already defined
# using train_test_split as in your code

# Linear Regression
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
linear_predictions = linear_model.predict(X_test)
linear_mse = mean_squared_error(y_test, linear_predictions)
print(f"Linear Regression MSE: {linear_mse}")

# Ridge Regression
ridge_model = Ridge(alpha=1.0)  # You can adjust the alpha parameter
ridge_model.fit(X_train, y_train)
ridge_predictions = ridge_model.predict(X_test)
ridge_mse = mean_squared_error(y_test, ridge_predictions)
print(f"Ridge Regression MSE: {ridge_mse}")

# Lasso Regression
lasso_model = Lasso(alpha=1.0)  # You can adjust the alpha parameter
lasso_model.fit(X_train, y_train)
lasso_predictions = lasso_model.predict(X_test)
lasso_mse = mean_squared_error(y_test, lasso_predictions)
print(f"Lasso Regression MSE: {lasso_mse}")

# Decision Tree Regression
tree_model = DecisionTreeRegressor()
tree_model.fit(X_train, y_train)
tree_predictions = tree_model.predict(X_test)
tree_mse = mean_squared_error(y_test, tree_predictions)
print(f"Decision Tree Regression MSE: {tree_mse}")
# Out:
# Linear Regression MSE: 0.6834198834970453
# Ridge Regression MSE: 0.6834050889328936
# Lasso Regression MSE: 0.8520683888297862
# Decision Tree Regression MSE: 0.8881130430192418
